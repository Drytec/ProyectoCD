# %%
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy as db
from sqlalchemy import create_engine
import yaml

# %%
with open('C:\\Users\\dylan\\OneDrive\\Documentos\\mensajeria\\config.yml', 'r') as f:
    config = yaml.safe_load(f)
    config_co = config['mensajeria']
    config_etl = config['ETL_PRO']

# Construct the database URL
url_co = (f"{config_co['drivername']}://{config_co['user']}:{config_co['password']}@{config_co['host']}:"
          f"{config_co['port']}/{config_co['dbname']}")
url_etl = (f"{config_etl['drivername']}://{config_etl['user']}:{config_etl['password']}@{config_etl['host']}:"
           f"{config_etl['port']}/{config_etl['dbname']}")
# Create the SQLAlchemy Engine
mensajeria = create_engine(url_co)
etl_conn = create_engine(url_etl)

# %%
tabla_sede = pd.read_sql_table('sede', mensajeria)
tabla_sede.tail(10)
# Out:
#     sede_id                  nombre                    direccion   telefono  \
# 42       50               RECUPERAR  Los angeles distrito Latino  310-70000
# 43       38                HEMOLIFE  Los angeles distrito Latino  310-70000
# 44       31              CRISTO REY  Los angeles distrito Latino  310-70000
# 45       52            NUEVA HEMATO  Los angeles distrito Latino  310-70000
# 46       53            NUEVA HEMATO  Los angeles distrito Latino  310-70000
# 47       54            NUEVA HEMATO  Los angeles distrito Latino  310-70000
# 48       85                   CIMEX  Los angeles distrito Latino  310-70000
# 49        3     TORRES DE MARACAIBO  Los angeles distrito Latino  310-70000
# 50        4                 INGENIO  Los angeles distrito Latino  310-70000
# 51       12  PALMA REAL / LOS ROJOS  Los angeles distrito Latino  310-70000
#
#    nombre_contacto  ciudad_id  cliente_id
# 42      JUAN PEREZ          1          15
# 43      JUAN PEREZ          1           3
# 44      JUAN PEREZ          1           7
# 45      JUAN PEREZ          1           8
# 46      JUAN PEREZ          1           8
# 47      JUAN PEREZ          1           8
# 48      JUAN PEREZ          1          27
# 49      JUAN PEREZ          1           5
# 50      JUAN PEREZ          1           5
# 51      JUAN PEREZ          2           4

# %%
tabla_sede.to_sql('dim_sede', etl_conn, if_exists='replace', index=False)
# Out:
# 52
